# %% [markdown]
# # Download ENTSO-E data
#
# This notebook is not intended to be shared with students, it is just for us to download the data from ENTSO-E and save it in a CSV file which we share with the students.

# %%
import os
#!pip install entsoe-py
from entsoe.files import EntsoeFileClient
import os
import pandas as pd
import numpy as np
import datetime
import glob
from pathlib import Path

PICKLE_FILE = "entsoe-demand-shortened.pickle"

CATEGORY = "ActualTotalLoad_6.1.A"

# %%
from getpass import getpass
user = getpass('User for ENTSO-E API:')
pwd = getpass('Password for ENTSO-E API:')

# %%
client = EntsoeFileClient(username=user, pwd=pwd)

# %%
file_list = client.list_folder(CATEGORY)

# %%
file_list
# Out:
# {'2014_12_ActualTotalLoad_6.1.A.csv': '042e638d-8c23-47f9-8cac-29e83b46bb0a',
#  '2015_01_ActualTotalLoad_6.1.A.csv': 'ad1875f9-2ac8-480e-af92-41c44f193d5c',
#  '2015_02_ActualTotalLoad_6.1.A.csv': '63b22bd1-6761-4594-ae2e-98cef6fbbe04',
#  '2015_03_ActualTotalLoad_6.1.A.csv': 'd85396f6-ef70-4514-aff5-83687dcea94d',
#  '2015_04_ActualTotalLoad_6.1.A.csv': '5358dd81-1abe-44bb-b187-64264cb2e8f9',
#  '2015_05_ActualTotalLoad_6.1.A.csv': '868e78b6-2c40-48f6-a6a6-d0c2e9da14a9',
#  '2015_06_ActualTotalLoad_6.1.A.csv': '4d769b72-b885-421f-98fb-5fd7d5cfeaa0',
#  '2015_07_ActualTotalLoad_6.1.A.csv': '41464686-1f25-4adf-a612-5a6d2c1528f0',
#  '2015_08_ActualTotalLoad_6.1.A.csv': '88ee046a-bccf-41a3-a6e9-3a0e1e5dd40e',
#  '2015_09_ActualTotalLoad_6.1.A.csv': '508dfbb6-5908-4208-b08f-7b81d065c744',
#  '2015_10_ActualTotalLoad_6.1.A.csv': 'cbaad858-5e7f-4388-b1c5-38256e40da86',
#  '2015_11_ActualTotalLoad_6.1.A.csv': 'bb97dcff-8fad-48c2-bd33-1a36b17e6b27',
# ...

# %%
l = list(file_list.keys())
df = pd.DataFrame()
for k in l:
    df = pd.concat([df, client.download_single_file(folder=CATEGORY, filename=k)])

# %%
df = df.set_index(pd.to_datetime(df['DateTime'])).sort_index()

# %%
power_demand_shortened = df[df["AreaTypeCode"]=='CTY'][["ResolutionCode", "AreaName","TotalLoadValue"]]

# %%
power_demand_shortened.to_pickle(PICKLE_FILE)
