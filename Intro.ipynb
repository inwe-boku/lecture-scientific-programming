# %% [markdown]
# # An introduction to scientific programming
#
# Welcome to the lecture :)
#
# We will start at 14:00.
#
#
# If you haven't done so yet, please fill out this survey:
#
# **https://www.menti.com/ov1kaxvboa**
#
# ![QR Code for Menti](https://storage2.me-qr.com/qr/270762578.png?v=1762166602)
#
# <br><br>
#
# Furthermore, please prepare a browser window and login with your Google account!
