# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
red = 197

# %%
green = 198

# %%
blue = 202

# %%
# to show the color selected above we simply plot a rectangle
plt.gca().add_artist(matplotlib.patches.Rectangle((0,0), 1, 1, color=(red/255, green/255, blue/255)));
